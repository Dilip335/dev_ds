# %%
# %sql
show databases

# %%
display(dbutils.fs.ls("/Volumes/main/dbdemos_sdp_cdc/raw_data/customers/"))

# %%
df=spark.read.format("json").option("header","true").load("/Volumes/main/dbdemos_sdp_cdc/raw_data/customers/part-00000-tid-5803582304861279886-9fddac41-b463-4dcd-a362-baa7830b8e2d-331-1-c000.json")

# %%
display(df)

# %%
# %sql
USE main.dbdemos_sdp_cdc

# %%
# %sql
SHOW TABLES

# %%
db = "main.dbdemos_sdp_cdc"

df_custoemrs                =spark.table(f"{db}.customers")
df_customers_cdc            =spark.table(f"{db}.customers_cdc")
df_customers_cdc_clean      =spark.table(f"{db}.customers_cdc_clean")
df_dbdemos_cdc_event_logs   =spark.table(f"{db}.dbdemos_cdc_event_logs")
df_scd2_customers           =spark.table(f"{db}.scd2_customers")

# %%
db

df1=spark.table("main.dbdemos_sdp_cdc.customers")

# %%
#display(df1)
print(df_custoemrs.count())
print(df_customers_cdc.count())
print(df_customers_cdc_clean.count())
print(df_dbdemos_cdc_event_logs.count())
print(df_scd2_customers.count())

# %%
# %sql
select * from main.dbdemos_sdp_cdc.customers_cdc

# %%
from pyspark.sql import functions as F

# Select specific columns
df_subset = df_customers_cdc.select("address","email","id")  
print(df_subset.count())
display(df_subset)

# %%
# Filter rows (e.g., finding customers in a specific country)
df_fileter= df_customers_cdc.filter(F.col("operation")=="UPDATE")

#df_fileter= df_customers_cdc.filter(F.col("operation")=="update")
#df_fileter= df_customers_cdc.filter(F.col("operation") == "deleter")

# %%
display(df_fileter)

# %%
## Add or update a column (e.g., making emails lowercase)
df_columnname= df_customers_cdc.withColumn("email_lower",F.upper(F.col("EMAIL")))
display(df_columnname)
